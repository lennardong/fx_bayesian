# %% [markdown]
# # Trends

# %%
from src._singletons import *
from src.chartmanager import *
from src.datamanager import *
from src.analytics import *
from pprint import pformat

# %% [markdown]
# ## Get Data

# %%
datamanager = AlphaVantageDataManager("SGD", "MYR")
# datamanager.query_endpoint()
df = datamanager.df
# Out:
# Processed DF for SGD/MYR:
#            from_symbol to_symbol     open     high      low    close
# date
# 2024-09-27         SGD       MYR  3.22640  3.22640  3.20540  3.22110
# 2024-09-26         SGD       MYR  3.21260  3.22534  3.20396  3.22530
# 2024-09-25         SGD       MYR  3.20980  3.22131  3.20145  3.20137
# 2024-09-24         SGD       MYR  3.23169  3.23169  3.20168  3.23562
# 2024-09-23         SGD       MYR  3.25389  3.26652  3.21506  3.25935
#            from_symbol to_symbol     open     high      low    close
# date
# 2024-05-19         SGD       MYR  3.48098  3.48282  3.47985  3.48291
# 2024-05-16         SGD       MYR  3.47948  3.47948  3.47325  3.47946
# 2024-05-15         SGD       MYR  3.48403  3.49631  3.47939  3.49631
# 2024-05-14         SGD       MYR  3.47976  3.50566  3.47976  3.48518
# 2024-05-13         SGD       MYR  3.49487  3.49670  3.47858  3.49243

# %% [markdown]
# ## Trend

# %%
chartmanager = ChartManager(df, "SGD/MYR Exchange Rate")
chartmanager.add_candlestick(
    CandleStickCols(open=ColName.OPEN, high=ColName.HIGH, low=ColName.LOW, close=ColName.CLOSE)
)
chartmanager.add_today_line()

# add key dates
key_dates = {
    date(2024, 9, 18): "US-FedRateCut", 
    date(2024, 10, 10): "JB-StateApproval", 
    date(2024, 11, 5): "US-Election", 
    date(2024, 11, 6): "US-FedMeeting", 
    date(2024, 12, 18): "US-FedMeeting", 
}
chartmanager.add_vline_date(key_dates)

# %%
ma_st = compute_rolling_average(df, ColName.CLOSE, 3, forward=False)
ma_lt = compute_rolling_average(df, ColName.CLOSE, 5, forward=False)
chartmanager.add_linetrace(ma_st, "MA-Short", colour = "blue")
chartmanager.add_linetrace(ma_lt, "MA-Long", colour = "purple")

print(f"ma_st: \n{pformat(ma_st, indent=4)}")
print(f"\n\n")
print(f"ma_lt: \n{pformat(ma_lt, indent=4)}")
# Out:
# ma_st:
# {   Timestamp('2024-05-13 00:00:00'): 3.49243,
#     Timestamp('2024-05-14 00:00:00'): 3.488805,
#     Timestamp('2024-05-15 00:00:00'): 3.4913066666666666,
#     Timestamp('2024-05-16 00:00:00'): 3.4869833333333333,
#     Timestamp('2024-05-19 00:00:00'): 3.4862266666666666,
#     Timestamp('2024-05-20 00:00:00'): 3.4789366666666672,
#     Timestamp('2024-05-21 00:00:00'): 3.47926,
#     Timestamp('2024-05-22 00:00:00'): 3.476573333333333,
#     Timestamp('2024-05-23 00:00:00'): 3.4777766666666667,
#     Timestamp('2024-05-26 00:00:00'): 3.4804366666666664,
#     Timestamp('2024-05-27 00:00:00'): 3.4817199999999997,
#     Timestamp('2024-05-28 00:00:00'): 3.48192,
#     Timestamp('2024-05-29 00:00:00'): 3.4784633333333335,
#     Timestamp('2024-05-30 00:00:00'): 3.480446666666667,
#     Timestamp('2024-06-02 00:00:00'): 3.4816933333333338,
#     Timestamp('2024-06-03 00:00:00'): 3.4879233333333333,
#     Timestamp('2024-06-04 00:00:00'): 3.489796666666667,
#     Timestamp('2024-06-05 00:00:00'): 3.4905299999999997,
#     Timestamp('2024-06-06 00:00:00'): 3.487156666666667,
#     Timestamp('2024-06-09 00:00:00'): 3.4792466666666666,
#     Timestamp('2024-06-10 00:00:00'): 3.4799833333333337,
#     Timestamp('2024-06-11 00:00:00'): 3.4798033333333334,
#     Timestamp('2024-06-12 00:00:00'): 3.4902933333333332,
#     Timestamp('2024-06-13 00:00:00'): 3.489323333333333,
#     Timestamp('2024-06-16 00:00:00'): 3.4889266666666665,
#     Timestamp('2024-06-17 00:00:00'): 3.48593,
#     Timestamp('2024-06-18 00:00:00'): 3.4871766666666666,
#     Timestamp('2024-06-19 00:00:00'): 3.486593333333333,
#     Timestamp('2024-06-20 00:00:00'): 3.4825366666666664,
#     Timestamp('2024-06-23 00:00:00'): 3.478543333333333,
#     Timestamp('2024-06-24 00:00:00'): 3.4775233333333335,
#     Timestamp('2024-06-25 00:00:00'): 3.4756099999999996,
#     Timestamp('2024-06-26 00:00:00'): 3.472746666666666,
#     Timestamp('2024-06-27 00:00:00'): 3.471463333333334,
#     Timestamp('2024-06-30 00:00:00'): 3.474243333333334,
#     Timestamp('2024-07-01 00:00:00'): 3.4748133333333335,
#     Timestamp('2024-07-02 00:00:00'): 3.473513333333333,
#     Timestamp('2024-07-03 00:00:00'): 3.475376666666667,
#     Timestamp('2024-07-04 00:00:00'): 3.4797466666666668,
#     Timestamp('2024-07-07 00:00:00'): 3.4858100000000003,
#     Timestamp('2024-07-08 00:00:00'): 3.4866566666666667,
#     Timestamp('2024-07-09 00:00:00'): 3.4875566666666664,
#     Timestamp('2024-07-10 00:00:00'): 3.4852199999999995,
#     Timestamp('2024-07-11 00:00:00'): 3.48611,
#     Timestamp('2024-07-14 00:00:00'): 3.483076666666667,
#     Timestamp('2024-07-15 00:00:00'): 3.480376666666667,
#     Timestamp('2024-07-16 00:00:00'): 3.476216666666667,
#     Timestamp('2024-07-17 00:00:00'): 3.478263333333333,
#     Timestamp('2024-07-18 00:00:00'): 3.47954,
#     Timestamp('2024-07-21 00:00:00'): 3.48245,
#     Timestamp('2024-07-22 00:00:00'): 3.4821833333333334,
#     Timestamp('2024-07-23 00:00:00'): 3.481116666666667,
#     Timestamp('2024-07-24 00:00:00'): 3.4781366666666664,
#     Timestamp('2024-07-25 00:00:00'): 3.47725,
#     Timestamp('2024-07-28 00:00:00'): 3.474073333333333,
#     Timestamp('2024-07-29 00:00:00'): 3.4650466666666664,
#     Timestamp('2024-07-30 00:00:00'): 3.4527733333333335,
#     Timestamp('2024-07-31 00:00:00'): 3.44009,
#     Timestamp('2024-08-01 00:00:00'): 3.42832,
#     Timestamp('2024-08-04 00:00:00'): 3.4109466666666663,
#     Timestamp('2024-08-05 00:00:00'): 3.380713333333333,
#     Timestamp('2024-08-06 00:00:00'): 3.36632,
#     Timestamp('2024-08-07 00:00:00'): 3.3647666666666667,
#     Timestamp('2024-08-08 00:00:00'): 3.376326666666667,
#     Timestamp('2024-08-11 00:00:00'): 3.3650366666666667,
#     Timestamp('2024-08-12 00:00:00'): 3.3568366666666662,
#     Timestamp('2024-08-13 00:00:00'): 3.3597900000000003,
#     Timestamp('2024-08-14 00:00:00'): 3.365623333333333,
#     Timestamp('2024-08-15 00:00:00'): 3.3630833333333334,
#     Timestamp('2024-08-18 00:00:00'): 3.3563066666666668,
#     Timestamp('2024-08-19 00:00:00'): 3.3532699999999998,
#     Timestamp('2024-08-20 00:00:00'): 3.35324,
#     Timestamp('2024-08-21 00:00:00'): 3.3489566666666666,
#     Timestamp('2024-08-22 00:00:00'): 3.349526666666667,
#     Timestamp('2024-08-25 00:00:00'): 3.3523333333333336,
#     Timestamp('2024-08-26 00:00:00'): 3.3481733333333334,
#     Timestamp('2024-08-27 00:00:00'): 3.3438933333333334,
#     Timestamp('2024-08-28 00:00:00'): 3.3345366666666667,
#     Timestamp('2024-08-29 00:00:00'): 3.3251566666666665,
#     Timestamp('2024-09-01 00:00:00'): 3.31669,
#     Timestamp('2024-09-02 00:00:00'): 3.3156,
#     Timestamp('2024-09-03 00:00:00'): 3.325196666666667,
#     Timestamp('2024-09-04 00:00:00'): 3.3318100000000004,
#     Timestamp('2024-09-05 00:00:00'): 3.332546666666667,
#     Timestamp('2024-09-08 00:00:00'): 3.329463333333333,
#     Timestamp('2024-09-09 00:00:00'): 3.3323066666666663,
#     Timestamp('2024-09-10 00:00:00'): 3.32997,
#     Timestamp('2024-09-11 00:00:00'): 3.3286433333333334,
#     Timestamp('2024-09-12 00:00:00'): 3.3246366666666667,
#     Timestamp('2024-09-15 00:00:00'): 3.32072,
#     Timestamp('2024-09-16 00:00:00'): 3.31879,
#     Timestamp('2024-09-17 00:00:00'): 3.30625,
#     Timestamp('2024-09-18 00:00:00'): 3.293053333333333,
#     Timestamp('2024-09-19 00:00:00'): 3.2734433333333333,
#     Timestamp('2024-09-22 00:00:00'): 3.2626600000000003,
#     Timestamp('2024-09-23 00:00:00'): 3.2580466666666665,
#     Timestamp('2024-09-24 00:00:00'): 3.250443333333333,
#     Timestamp('2024-09-25 00:00:00'): 3.232113333333333,
#     Timestamp('2024-09-26 00:00:00'): 3.2207633333333328,
#     Timestamp('2024-09-27 00:00:00'): 3.215923333333333}
#
#
#
# ma_lt:
# {   Timestamp('2024-05-13 00:00:00'): 3.49243,
#     Timestamp('2024-05-14 00:00:00'): 3.488805,
#     Timestamp('2024-05-15 00:00:00'): 3.4913066666666666,
#     Timestamp('2024-05-16 00:00:00'): 3.488345,
#     Timestamp('2024-05-19 00:00:00'): 3.4872579999999997,
#     Timestamp('2024-05-20 00:00:00'): 3.4836599999999995,
#     Timestamp('2024-05-21 00:00:00'): 3.48271,
#     Timestamp('2024-05-22 00:00:00'): 3.478418,
#     Timestamp('2024-05-23 00:00:00'): 3.478136,
#     Timestamp('2024-05-26 00:00:00'): 3.479236,
#     Timestamp('2024-05-27 00:00:00'): 3.480088,
#     Timestamp('2024-05-28 00:00:00'): 3.479732,
#     Timestamp('2024-05-29 00:00:00'): 3.4803699999999997,
#     Timestamp('2024-05-30 00:00:00'): 3.4816899999999995,
#     Timestamp('2024-06-02 00:00:00'): 3.480486,
#     Timestamp('2024-06-03 00:00:00'): 3.4840919999999995,
#     Timestamp('2024-06-04 00:00:00'): 3.4864159999999997,
#     Timestamp('2024-06-05 00:00:00'): 3.487726,
#     Timestamp('2024-06-06 00:00:00'): 3.488118,
#     Timestamp('2024-06-09 00:00:00'): 3.484948,
#     Timestamp('2024-06-10 00:00:00'): 3.4829620000000006,
#     Timestamp('2024-06-11 00:00:00'): 3.4821220000000004,
#     Timestamp('2024-06-12 00:00:00'): 3.484806,
#     Timestamp('2024-06-13 00:00:00'): 3.484262,
#     Timestamp('2024-06-16 00:00:00'): 3.48793,
#     Timestamp('2024-06-17 00:00:00'): 3.4883740000000003,
#     Timestamp('2024-06-18 00:00:00'): 3.488686,
#     Timestamp('2024-06-19 00:00:00'): 3.48571,
#     Timestamp('2024-06-20 00:00:00'): 3.4843020000000005,
#     Timestamp('2024-06-23 00:00:00'): 3.482456,
#     Timestamp('2024-06-24 00:00:00'): 3.4806660000000003,
#     Timestamp('2024-06-25 00:00:00'): 3.4773620000000003,
#     Timestamp('2024-06-26 00:00:00'): 3.4741480000000005,
#     Timestamp('2024-06-27 00:00:00'): 3.474022,
#     Timestamp('2024-06-30 00:00:00'): 3.474782,
#     Timestamp('2024-07-01 00:00:00'): 3.472522,
#     Timestamp('2024-07-02 00:00:00'): 3.472764,
#     Timestamp('2024-07-03 00:00:00'): 3.4763600000000006,
#     Timestamp('2024-07-04 00:00:00'): 3.4774919999999994,
#     Timestamp('2024-07-07 00:00:00'): 3.4797039999999995,
#     Timestamp('2024-07-08 00:00:00'): 3.483466,
#     Timestamp('2024-07-09 00:00:00'): 3.4859180000000003,
#     Timestamp('2024-07-10 00:00:00'): 3.48561,
#     Timestamp('2024-07-11 00:00:00'): 3.487284,
#     Timestamp('2024-07-14 00:00:00'): 3.4842779999999998,
#     Timestamp('2024-07-15 00:00:00'): 3.4818420000000003,
#     Timestamp('2024-07-16 00:00:00'): 3.48048,
#     Timestamp('2024-07-17 00:00:00'): 3.480104,
#     Timestamp('2024-07-18 00:00:00'): 3.4778999999999995,
#     Timestamp('2024-07-21 00:00:00'): 3.480104,
#     Timestamp('2024-07-22 00:00:00'): 3.4811880000000004,
#     Timestamp('2024-07-23 00:00:00'): 3.4808399999999997,
#     Timestamp('2024-07-24 00:00:00'): 3.480028,
#     Timestamp('2024-07-25 00:00:00'): 3.4798139999999997,
#     Timestamp('2024-07-28 00:00:00'): 3.4758139999999997,
#     Timestamp('2024-07-29 00:00:00'): 3.4697459999999998,
#     Timestamp('2024-07-30 00:00:00'): 3.462808,
#     Timestamp('2024-07-31 00:00:00'): 3.452986,
#     Timestamp('2024-08-01 00:00:00'): 3.440388,
#     Timestamp('2024-08-04 00:00:00'): 3.4249319999999996,
#     Timestamp('2024-08-05 00:00:00'): 3.402386,
#     Timestamp('2024-08-06 00:00:00'): 3.388516,
#     Timestamp('2024-08-07 00:00:00'): 3.3797379999999997,
#     Timestamp('2024-08-08 00:00:00'): 3.37119,
#     Timestamp('2024-08-11 00:00:00'): 3.3609700000000005,
#     Timestamp('2024-08-12 00:00:00'): 3.365412,
#     Timestamp('2024-08-13 00:00:00'): 3.367272,
#     Timestamp('2024-08-14 00:00:00'): 3.361484,
#     Timestamp('2024-08-15 00:00:00'): 3.3574659999999996,
#     Timestamp('2024-08-18 00:00:00'): 3.362034,
#     Timestamp('2024-08-19 00:00:00'): 3.359344,
#     Timestamp('2024-08-20 00:00:00'): 3.3535359999999996,
#     Timestamp('2024-08-21 00:00:00'): 3.3520339999999997,
#     Timestamp('2024-08-22 00:00:00'): 3.3512100000000005,
#     Timestamp('2024-08-25 00:00:00'): 3.351152,
#     Timestamp('2024-08-26 00:00:00'): 3.3489760000000004,
#     Timestamp('2024-08-27 00:00:00'): 3.3456019999999995,
#     Timestamp('2024-08-28 00:00:00'): 3.3425,
#     Timestamp('2024-08-29 00:00:00'): 3.334354,
#     Timestamp('2024-09-01 00:00:00'): 3.324216,
#     Timestamp('2024-09-02 00:00:00'): 3.322956,
#     Timestamp('2024-09-03 00:00:00'): 3.3231360000000003,
#     Timestamp('2024-09-04 00:00:00'): 3.32258,
#     Timestamp('2024-09-05 00:00:00'): 3.32739,
#     Timestamp('2024-09-08 00:00:00'): 3.3308,
#     Timestamp('2024-09-09 00:00:00'): 3.332604,
#     Timestamp('2024-09-10 00:00:00'): 3.330254,
#     Timestamp('2024-09-11 00:00:00'): 3.3289,
#     Timestamp('2024-09-12 00:00:00'): 3.327858,
#     Timestamp('2024-09-15 00:00:00'): 3.3250079999999995,
#     Timestamp('2024-09-16 00:00:00'): 3.32079,
#     Timestamp('2024-09-17 00:00:00'): 3.313626,
#     Timestamp('2024-09-18 00:00:00'): 3.3036540000000003,
#     Timestamp('2024-09-19 00:00:00'): 3.2900739999999997,
#     Timestamp('2024-09-22 00:00:00'): 3.27879,
#     Timestamp('2024-09-23 00:00:00'): 3.267208,
#     Timestamp('2024-09-24 00:00:00'): 3.25659,
#     Timestamp('2024-09-25 00:00:00'): 3.242226,
#     Timestamp('2024-09-26 00:00:00'): 3.2356000000000003,
#     Timestamp('2024-09-27 00:00:00'): 3.228548}

# %%
rsi_14 = compute_relative_strength_index(df, ColName.CLOSE, 14)
rsi_3 = compute_relative_strength_index(df, ColName.CLOSE, 3)
chartmanager.add_linetrace(rsi_14, "RSI 14", "red", True )
chartmanager.add_linetrace(rsi_3, "RSI 3", "brown", True)

# %%
chartmanager.show()
